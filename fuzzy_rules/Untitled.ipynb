# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("scores.csv")

# %%
data
# Out:
#       序号        品牌                        名称       类型  出厂年份  \
# 0      1     Apple     2019 MacBook Pro 15.4      高端本  2019
# 1      2     Apple     2019 MacBook Pro 15.4      高端本  2019
# 2      3     Apple     2019 MacBook Pro 15.4      高端本  2019
# 3      4     Apple     2019 MacBook Pro 13.3      高端本  2019
# 4      5     Apple     2019 MacBook Pro 13.3      高端本  2019
# 5      6     Apple     2018 MacBook Pro 13.3      高端本  2018
# 6      7     Apple     2017 MacBook Pro 13.3      高端本  2017
# 7      8  ThinkPad        2019 ThinkPad T490      开发本  2019
# 8      9  ThinkPad        2019 ThinkPad T490      开发本  2019
# 9     10  ThinkPad        2019 ThinkPad T490      开发本  2019
# 10    11  ThinkPad       2019 ThinkPad T490s      高端本  2019
# 11    12  ThinkPad       2019 ThinkPad T490s      高端本  2019
# 12    13  ThinkPad       2019 ThinkPad T490s      高端本  2019
# 13    14  ThinkPad       2019 ThinkPad T490s      高端本  2019
# 14    15  ThinkPad        2018 ThinkPad T480      开发本  2018
# ...

# %%
import csv

# %%
csv_file=open('scores.csv')

# %%
csv_reader_lines = csv.reader(csv_file)

# %%
for line in csv_reader_lines:
    print(eval(line[4]))
# Out:
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2017
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2018
# 2018
# 2018
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2018
# 2018
# 2019
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2019
# 2019
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2019
# 2019
# 2019
# 2018
# 2018
# 2018
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2019
# 2019
# 2018
# 2018
# 2018
# 2018
# 2018
# 2018
# 2019
# 2019
# 2019
# 2019
# 2018
# 2018
# 2019
# 2019
# 2019
# 2019
# 2018
# 2018
# 2018
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2019
# 2018
# 2018
# 2019
# 2019
# 2018
# 2018
# 2018
# ...
